# %%
# !pip install neuralprophet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: neuralprophet in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (0.3.0)
# Requirement already satisfied: convertdate>=2.1.2 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from neuralprophet) (2.3.2)
# Requirement already satisfied: holidays>=0.11.3.1 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from neuralprophet) (0.12)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from neuralprophet) (3.5.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from neuralprophet) (2.8.2)
# Requirement already satisfied: torch-lr-finder>=0.2.1 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from neuralprophet) (0.2.1)
# Requirement already satisfied: LunarCalendar>=0.0.9 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from neuralprophet) (0.0.9)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from neuralprophet) (1.3.5)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from neuralprophet) (1.21.5)
# Requirement already satisfied: tqdm>=4.50.2 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from neuralprophet) (4.62.3)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from neuralprophet) (7.6.5)
# Requirement already satisfied: torch>=1.4.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from neuralprophet) (1.10.1)
# Requirement already satisfied: dataclasses>=0.6 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from neuralprophet) (0.6)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from convertdate>=2.1.2->neuralprophet) (0.5.11)
# Requirement already satisfied: pytz>=2014.10 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from convertdate>=2.1.2->neuralprophet) (2021.3)
# Requirement already satisfied: hijri-converter in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from holidays>=0.11.3.1->neuralprophet) (2.2.2)
# Requirement already satisfied: korean-lunar-calendar in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from holidays>=0.11.3.1->neuralprophet) (0.2.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipywidgets>=7.5.1->neuralprophet) (1.0.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipywidgets>=7.5.1->neuralprophet) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipywidgets>=7.5.1->neuralprophet) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipywidgets>=7.5.1->neuralprophet) (3.5.2)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipywidgets>=7.5.1->neuralprophet) (7.31.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipywidgets>=7.5.1->neuralprophet) (5.1.3)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipywidgets>=7.5.1->neuralprophet) (6.7.0)
# Requirement already satisfied: ephem>=3.7.5.3 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from LunarCalendar>=0.0.9->neuralprophet) (4.1.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from matplotlib>=2.0.0->neuralprophet) (3.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from matplotlib>=2.0.0->neuralprophet) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from matplotlib>=2.0.0->neuralprophet) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from matplotlib>=2.0.0->neuralprophet) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from matplotlib>=2.0.0->neuralprophet) (9.0.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from matplotlib>=2.0.0->neuralprophet) (4.28.5)
# Requirement already satisfied: six>=1.5 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from python-dateutil>=2.8.0->neuralprophet) (1.16.0)
# Requirement already satisfied: typing-extensions in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from torch>=1.4.0->neuralprophet) (4.0.1)
# Requirement already satisfied: colorama in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from tqdm>=4.50.2->neuralprophet) (0.4.4)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (7.1.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (0.1.3)
# Requirement already satisfied: nest-asyncio in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (1.5.4)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (6.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (3.0.24)
# Requirement already satisfied: decorator in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\program files\python37\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (40.8.0)
# Requirement already satisfied: backcall in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.18.1)
# Requirement already satisfied: pygments in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (2.11.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->neuralprophet) (4.4.0)
# Requirement already satisfied: jupyter-core in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->neuralprophet) (4.9.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (6.4.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.8.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->neuralprophet) (5.4.0)
# Requirement already satisfied: importlib-metadata in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->neuralprophet) (4.10.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->neuralprophet) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->neuralprophet) (21.4.0)
# Requirement already satisfied: entrypoints in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (0.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->neuralprophet) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.5.1->neuralprophet) (303)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.8.0)
# Requirement already satisfied: jinja2 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (3.0.3)
# Requirement already satisfied: argon2-cffi in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (21.3.0)
# Requirement already satisfied: nbconvert in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (6.4.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.12.1)
# Requirement already satisfied: prometheus-client in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.12.0)
# Requirement already satisfied: wcwidth in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->neuralprophet) (0.2.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from importlib-resources>=1.4.0->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->neuralprophet) (3.7.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.1.6)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (2.0.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.5.10)
# Requirement already satisfied: testpath in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.7.1)
# Requirement already satisfied: bleach in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (4.1.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (1.15.0)
# Requirement already satisfied: webencodings in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\jeevitha\appdata\roaming\python\python37\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->neuralprophet) (2.21)

# %%
import pandas as pd
from neuralprophet import NeuralProphet
from matplotlib import pyplot as plt
import pickle
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv('weatherAUS.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
df.Location.unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
plt.plot(melb['Date'], melb['Temp3pm'])
plt.show()

# %%
melb['Year'] = melb['Date'].apply(lambda x: x.year)
melb = melb[melb['Year']<=2015]
plt.plot(melb['Date'], melb['Temp3pm'])
plt.show()
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Users\Jeevitha\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
melb.tail()
# Out:
#             Date   Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 69846 2015-12-27  Melbourne      NaN      NaN       NaN          4.4
# 69847 2015-12-28  Melbourne      NaN      NaN       NaN          6.0
# 69848 2015-12-29  Melbourne      NaN      NaN       NaN          8.0
# 69849 2015-12-30  Melbourne      NaN      NaN       NaN          7.0
# 69850 2015-12-31  Melbourne      NaN      NaN       NaN         15.2
#
#        Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 69846       8.9         SSE           48.0        SSW  ...         NaN
# 69847      13.3         SSE           39.0          S  ...         NaN
# 69848      13.4           S           35.0        SSE  ...         NaN
# 69849      12.4         SSE           44.0          E  ...         NaN
# 69850      11.4         NNW           48.0          N  ...         NaN
#
#        Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 69846          NaN          NaN       NaN       NaN      NaN      NaN
# 69847          NaN          NaN       NaN       NaN      NaN      NaN
# 69848          NaN          NaN       NaN       NaN      NaN      NaN
# 69849          NaN          NaN       NaN       NaN      NaN      NaN
# 69850          NaN          NaN       NaN       NaN      NaN      NaN
#
#        RainToday  RainTomorrow  Year
# 69846        NaN           NaN  2015
# 69847        NaN           NaN  2015
# 69848        NaN           NaN  2015
# 69849        NaN           NaN  2015
# 69850        NaN           NaN  2015
#
# [5 rows x 24 columns]

# %%
data = melb[['Date', 'Temp3pm']] 
data.dropna(inplace=True)
data.columns = ['ds', 'y'] 
data.head()
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Users\Jeevitha\AppData\Roaming\Python\Python37\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#               ds     y
# 67200 2008-07-01  14.6
# 67201 2008-07-02  13.7
# 67202 2008-07-03  13.9
# 67203 2008-07-04  13.1
# 67204 2008-07-05  14.6

# %%
data
# Out:
#               ds     y
# 67200 2008-07-01  14.6
# 67201 2008-07-02  13.7
# 67202 2008-07-03  13.9
# 67203 2008-07-04  13.1
# 67204 2008-07-05  14.6
# ...          ...   ...
# 69486 2015-01-01  23.7
# 69487 2015-01-02  37.7
# 69488 2015-01-03  37.4
# 69489 2015-01-04  21.8
# 69490 2015-01-05  22.4
#
# [2288 rows x 2 columns]

# %%
m = NeuralProphet()
m.fit(data, freq='D', epochs=1000)
# Out:
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
#   0%|          | 0/268 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.65E-02, min: 1.40E+00
#   0%|          | 0/268 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.37E-02, min: 1.11E+00
#   0%|          | 0/268 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.37E-02, min: 1.30E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 3.46E-02
# Epoch[1000/1000]: 100%|███████| 1000/1000 [03:07<00:00,  5.34it/s, SmoothL1Loss=0.0144, MAE=3.02, RMSE=3.93, RegLoss=0]

# %%
future = m.make_future_dataframe(data, periods=900)
forecast = m.predict(future)
forecast.head()
# Out:
#           ds     y      yhat1 residual1      trend  season_yearly  \
# 0 2015-01-06  None  26.171215       NaN  20.683180       5.267790
# 1 2015-01-07  None  26.087841       NaN  20.686357       5.415779
# 2 2015-01-08  None  26.383972       NaN  20.689537       5.560784
# 3 2015-01-09  None  26.467545       NaN  20.692715       5.702022
# 4 2015-01-10  None  26.521069       NaN  20.695892       5.838734
#
#    season_weekly
# 0       0.220243
# 1      -0.014296
# 2       0.133650
# 3       0.072807
# 4      -0.013559

# %%
future
# Out:
#             ds     y
# 0   2015-01-06  None
# 1   2015-01-07  None
# 2   2015-01-08  None
# 3   2015-01-09  None
# 4   2015-01-10  None
# ..         ...   ...
# 895 2017-06-19  None
# 896 2017-06-20  None
# 897 2017-06-21  None
# 898 2017-06-22  None
# 899 2017-06-23  None
#
# [900 rows x 2 columns]

# %%
plot1 = m.plot(forecast)

# %%
plot1 = m.plot(forecast)

# %%
plt2 = m.plot_components(forecast)

# %%
with open('saved_model.pkl', "wb") as f:
    pickle.dump(m, f)

# %%
del m

# %%
with open('saved_model.pkl', "rb") as f:
    m = pickle.load(f)

# %%
future = m.make_future_dataframe(data, periods=1900)
forecast = m.predict(future)
forecast.head()
# Out:
#           ds     y      yhat1 residual1      trend  season_yearly  \
# 0 2015-01-06  None  26.171215       NaN  20.683180       5.267790
# 1 2015-01-07  None  26.087841       NaN  20.686357       5.415779
# 2 2015-01-08  None  26.383972       NaN  20.689537       5.560784
# 3 2015-01-09  None  26.467545       NaN  20.692715       5.702022
# 4 2015-01-10  None  26.521069       NaN  20.695892       5.838734
#
#    season_weekly
# 0       0.220243
# 1      -0.014296
# 2       0.133650
# 3       0.072807
# 4      -0.013559

# %%
plot1 = m.plot(forecast)
